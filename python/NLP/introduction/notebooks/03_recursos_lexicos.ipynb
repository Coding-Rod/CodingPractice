# %%
import nltk 
nltk.download('book')
from nltk.book import *
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/rodri/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to /home/rodri/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to /home/rodri/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package names to /home/rodri/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package timit to /home/rodri/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package udhr to /home/rodri/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to /home/rodri/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /home/rodri/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package punkt to /home/rodri/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/rodri/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection book
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# # Recursos léxicos (lexicons)
#
# *   Son colecciones de palabras o frases que tienen asociadas etiquetas o meta-informacion de algún tipo (POS tags, significados gramaticales, etc ...)
#
# **comentario:** POS (Part of Speech), también llamado etiquetado gramatical o etiquetado de palabras por categorias, consiste en etiquetar la categoria gramatical a la que pertence cada palabra en un volumen de texto, siendo las categorias:
#
# 1.   Sustantivos
# 2.   Adjetivos
# 3.   Articulos
# 4.   Pronombres
# 5.   Verbos
# 6.   Adverbios
# 7.   Interjecciones
# 8.   Preposiciones
# 9.   Conjunciones

# %%
# Vocabularios: palabras únicas en un corpus
vocab = sorted(set(text1))

# %%
# Distribuciones: frecuencia de aparición
word_freq = FreqDist(text1)

# %%
# Stopwords: Palabras muy usadas en el lenguaje que usualmente son filtradas en un pipeline de NLP (useless words)
print(stopwords.words('spanish'))
# Out:
# ['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los', 'del', 'se', 'las', 'por', 'un', 'para', 'con', 'no', 'una', 'su', 'al', 'lo', 'como', 'más', 'pero', 'sus', 'le', 'ya', 'o', 'este', 'sí', 'porque', 'esta', 'entre', 'cuando', 'muy', 'sin', 'sobre', 'también', 'me', 'hasta', 'hay', 'donde', 'quien', 'desde', 'todo', 'nos', 'durante', 'todos', 'uno', 'les', 'ni', 'contra', 'otros', 'ese', 'eso', 'ante', 'ellos', 'e', 'esto', 'mí', 'antes', 'algunos', 'qué', 'unos', 'yo', 'otro', 'otras', 'otra', 'él', 'tanto', 'esa', 'estos', 'mucho', 'quienes', 'nada', 'muchos', 'cual', 'poco', 'ella', 'estar', 'estas', 'algunas', 'algo', 'nosotros', 'mi', 'mis', 'tú', 'te', 'ti', 'tu', 'tus', 'ellas', 'nosotras', 'vosotros', 'vosotras', 'os', 'mío', 'mía', 'míos', 'mías', 'tuyo', 'tuya', 'tuyos', 'tuyas', 'suyo', 'suya', 'suyos', 'suyas', 'nuestro', 'nuestra', 'nuestros', 'nuestras', 'vuestro', 'vuestra', 'vuestros', 'vuestras', 'esos', 'esas', 'estoy', 'estás', 'está', 'estamos', 'estáis', 'están', 'esté', 'estés', 'estemos', 'estéis', 'estén', 'estaré', 'estarás', 'estará', 'estaremos', 'estaréis', 'estarán', 'estaría', 'estarías', 'estaríamos', 'estaríais', 'estarían', 'estaba', 'estabas', 'estábamos', 'estabais', 'estaban', 'estuve', 'estuviste', 'estuvo', 'estuvimos', 'estuvisteis', 'estuvieron', 'estuviera', 'estuvieras', 'estuviéramos', 'estuvierais', 'estuvieran', 'estuviese', 'estuvieses', 'estuviésemos', 'estuvieseis', 'estuviesen', 'estando', 'estado', 'estada', 'estados', 'estadas', 'estad', 'he', 'has', 'ha', 'hemos', 'habéis', 'han', 'haya', 'hayas', 'hayamos', 'hayáis', 'hayan', 'habré', 'habrás', 'habrá', 'habremos', 'habréis', 'habrán', 'habría', 'habrías', 'habríamos', 'habríais', 'habrían', 'había', 'habías', 'habíamos', 'habíais', 'habían', 'hube', 'hubiste', 'hubo', 'hubimos', 'hubisteis', 'hubieron', 'hubiera', 'hubieras', 'hubiéramos', 'hubierais', 'hubieran', 'hubiese', 'hubieses', 'hubiésemos', 'hubieseis', 'hubiesen', 'habiendo', 'habido', 'habida', 'habidos', 'habidas', 'soy', 'eres', 'es', 'somos', 'sois', 'son', 'sea', 'seas', 'seamos', 'seáis', 'sean', 'seré', 'serás', 'será', 'seremos', 'seréis', 'serán', 'sería', 'serías', 'seríamos', 'seríais', 'serían', 'era', 'eras', 'éramos', 'erais', 'eran', 'fui', 'fuiste', 'fue', 'fuimos', 'fuisteis', 'fueron', 'fuera', 'fueras', 'fuéramos', 'fuerais', 'fueran', 'fuese', 'fueses', 'fuésemos', 'fueseis', 'fuesen', 'sintiendo', 'sentido', 'sentida', 'sentidos', 'sentidas', 'siente', 'sentid', 'tengo', 'tienes', 'tiene', 'tenemos', 'tenéis', 'tienen', 'tenga', 'tengas', 'tengamos', 'tengáis', 'tengan', 'tendré', 'tendrás', 'tendrá', 'tendremos', 'tendréis', 'tendrán', 'tendría', 'tendrías', 'tendríamos', 'tendríais', 'tendrían', 'tenía', 'tenías', 'teníamos', 'teníais', 'tenían', 'tuve', 'tuviste', 'tuvo', 'tuvimos', 'tuvisteis', 'tuvieron', 'tuviera', 'tuvieras', 'tuviéramos', 'tuvierais', 'tuvieran', 'tuviese', 'tuvieses', 'tuviésemos', 'tuvieseis', 'tuviesen', 'teniendo', 'tenido', 'tenida', 'tenidos', 'tenidas', 'tened']

# %% [markdown]
# ## Fraccion de Stopwords en un corpus

# %%
def stopwords_percentage(text):
  '''
  aqui usamos un recurso léxico (stopwords) para filtrar un corpus
  '''
  stopwd = stopwords.words('english')
  content = [w  for w in text if w.lower() not in stopwd]
  return len(content)/len(text)

stopwords_percentage(text1)
# Out:
# 0.5862954769399469

# %% [markdown]
# ## Lexicons enriquecidos (listas comparativas de palabras)
#
# *   Construyendo diccionarios para traduccion de palabras en diferentes idiomas.

# %%
from nltk.corpus import swadesh
#idiomas disponibles
print(swadesh.fileids())
# Out:
# ['be', 'bg', 'bs', 'ca', 'cs', 'cu', 'de', 'en', 'es', 'fr', 'hr', 'it', 'la', 'mk', 'nl', 'pl', 'pt', 'ro', 'ru', 'sk', 'sl', 'sr', 'sw', 'uk']

# %%
print(swadesh.words('en'))
# Out:
# ['I', 'you (singular), thou', 'he', 'we', 'you (plural)', 'they', 'this', 'that', 'here', 'there', 'who', 'what', 'where', 'when', 'how', 'not', 'all', 'many', 'some', 'few', 'other', 'one', 'two', 'three', 'four', 'five', 'big', 'long', 'wide', 'thick', 'heavy', 'small', 'short', 'narrow', 'thin', 'woman', 'man (adult male)', 'man (human being)', 'child', 'wife', 'husband', 'mother', 'father', 'animal', 'fish', 'bird', 'dog', 'louse', 'snake', 'worm', 'tree', 'forest', 'stick', 'fruit', 'seed', 'leaf', 'root', 'bark (from tree)', 'flower', 'grass', 'rope', 'skin', 'meat', 'blood', 'bone', 'fat (noun)', 'egg', 'horn', 'tail', 'feather', 'hair', 'head', 'ear', 'eye', 'nose', 'mouth', 'tooth', 'tongue', 'fingernail', 'foot', 'leg', 'knee', 'hand', 'wing', 'belly', 'guts', 'neck', 'back', 'breast', 'heart', 'liver', 'drink', 'eat', 'bite', 'suck', 'spit', 'vomit', 'blow', 'breathe', 'laugh', 'see', 'hear', 'know (a fact)', 'think', 'smell', 'fear', 'sleep', 'live', 'die', 'kill', 'fight', 'hunt', 'hit', 'cut', 'split', 'stab', 'scratch', 'dig', 'swim', 'fly (verb)', 'walk', 'come', 'lie', 'sit', 'stand', 'turn', 'fall', 'give', 'hold', 'squeeze', 'rub', 'wash', 'wipe', 'pull', 'push', 'throw', 'tie', 'sew', 'count', 'say', 'sing', 'play', 'float', 'flow', 'freeze', 'swell', 'sun', 'moon', 'star', 'water', 'rain', 'river', 'lake', 'sea', 'salt', 'stone', 'sand', 'dust', 'earth', 'cloud', 'fog', 'sky', 'wind', 'snow', 'ice', 'smoke', 'fire', 'ashes', 'burn', 'road', 'mountain', 'red', 'green', 'yellow', 'white', 'black', 'night', 'day', 'year', 'warm', 'cold', 'full', 'new', 'old', 'good', 'bad', 'rotten', 'dirty', 'straight', 'round', 'sharp', 'dull', 'smooth', 'wet', 'dry', 'correct', 'near', 'far', 'right', 'left', 'at', 'in', 'with', 'and', 'if', 'because', 'name']

# %%
it2es = swadesh.entries(['it', 'es'])
print(it2es)
# Out:
# [('io', 'yo'), ('tu, Lei', 'tú, usted'), ('lui, egli', 'él'), ('noi', 'nosotros'), ('voi', 'vosotros, ustedes'), ('loro, essi', 'ellos, ellas'), ('questo', 'este'), ('quello', 'ese, aquel'), ('qui, qua', 'aquí, acá'), ('là', 'ahí, allí, allá'), ('chi', 'quien'), ('che', 'que'), ('dove', 'donde'), ('quando', 'cuando'), ('come', 'como'), ('non', 'no'), ('tutto', 'todo'), ('molti', 'muchos'), ('alcuni', 'algunos, unos'), ('pochi', 'poco'), ('altro', 'otro'), ('uno', 'uno'), ('due', 'dos'), ('tre', 'tres'), ('quattro', 'cuatro'), ('cinque', 'cinco'), ('grande', 'grande'), ('lungo', 'largo'), ('largo', 'ancho'), ('spesso', 'gordo'), ('pesante', 'pesado'), ('piccolo', 'pequeño'), ('corto', 'corto'), ('stretto', 'estrecho, angosto'), ('sottile', 'delgado, flaco'), ('donna', 'mujer'), ('uomo', 'hombre'), ('uomo', 'hombre'), ('bambino', 'niño'), ('moglie', 'esposa, mujer'), ('marito', 'esposo, marido'), ('madre', 'madre'), ('padre', 'padre'), ('animale', 'animal'), ('pesce', 'pez, pescado'), ('uccello', 'ave, pájaro'), ('cane', 'perro'), ('pidocchio', 'piojo'), ('serpente', 'serpiente, culebra'), ('verme', 'gusano'), ('albero', 'árbol'), ('foresta', 'bosque'), ('bastone', 'palo'), ('frutta', 'fruta'), ('seme', 'semilla'), ('foglia', 'hoja'), ('radice', 'raíz'), ('corteccia', 'corteza'), ('fiore', 'flor'), ('erba', 'hierba, pasto'), ('corda', 'cuerda'), ('pelle', 'piel'), ('carne', 'carne'), ('sangue', 'sangre'), ('osso', 'hueso'), ('grasso', 'grasa'), ('uovo', 'huevo'), ('corno', 'cuerno'), ('coda', 'cola'), ('piuma', 'pluma'), ('capelli', 'cabello, pelo'), ('testa', 'cabeza'), ('orecchio', 'oreja'), ('occhio', 'ojo'), ('naso', 'nariz'), ('bocca', 'boca'), ('dente', 'diente'), ('lingua', 'lengua'), ('unghia', 'uña'), ('piede', 'pie'), ('gamba', 'pierna'), ('ginocchio', 'rodilla'), ('mano', 'mano'), ('ala', 'ala'), ('pancia', 'barriga, vientre, panza'), ('intestino', 'entrañas, tripas'), ('collo', 'cuello'), ('schiena', 'espalda'), ('petto', 'pecho, seno'), ('cuore', 'corazón'), ('fegato', 'hígado'), ('bere', 'beber, tomar'), ('mangiare', 'comer'), ('mordere', 'morder'), ('succhiare', 'chupar'), ('sputare', 'escupir'), ('vomitare', 'vomitar'), ('soffiare', 'soplar'), ('respirare', 'respirar'), ('ridere', 'reír'), ('vedere', 'ver'), ('udire, sentire', 'oír'), ('sapere', 'saber'), ('pensare', 'pensar'), ('odorare, annusare', 'oler'), ('temere', 'temer'), ('dormire', 'dormir'), ('vivere', 'vivir'), ('morire', 'morir'), ('uccidere', 'matar'), ('combattere', 'pelear'), ('cacciare', 'cazar'), ('colpire', 'golpear'), ('tagliare', 'cortar'), ('dividere, separare', 'partir'), ('pugnalare', 'apuñalar'), ('graffiare', 'arañar, rascar'), ('scavare', 'cavar'), ('nuotare', 'nadar'), ('volare', 'volar'), ('camminare', 'caminar'), ('venire', 'venir'), ('distendersi', 'echarse, acostarse, tenderse'), ('sedere', 'sentarse'), ('stare in piedi', 'estar de pie'), ('girare', 'voltear'), ('cadere', 'caer'), ('dare', 'dar'), ('tenere', 'sostener'), ('spremere', 'apretar'), ('strofinare', 'frotar'), ('lavare', 'lavar'), ('asciugare', 'limpiar'), ('tirare', 'tirar'), ('spingere', 'empujar'), ('tirare', 'tirar'), ('legare', 'atar'), ('cucire', 'coser'), ('contare', 'contar'), ('dire', 'decir'), ('cantare', 'cantar'), ('giocare', 'jugar'), ('galleggiare', 'flotar'), ('fluire', 'fluir'), ('gelare', 'helar'), ('gonfiare', 'hincharse'), ('sole', 'sol'), ('luna', 'luna'), ('stella', 'estrella'), ('acqua', 'agua'), ('pioggia', 'lluvia'), ('fiume', 'río'), ('lago', 'lago'), ('mare', 'mar'), ('sale', 'sal'), ('pietra', 'piedra'), ('sabbia', 'arena'), ('polvere', 'polvo'), ('terra', 'tierra'), ('nuvola', 'nube'), ('nebbia', 'niebla'), ('cielo', 'cielo'), ('vento', 'viento'), ('neve', 'nieve'), ('ghiaccio', 'hielo'), ('fumo', 'humo'), ('fuoco', 'fuego'), ('ceneri', 'cenizas'), ('bruciare', 'quemar'), ('strada', 'camino'), ('montagna', 'montaña'), ('rosso', 'rojo'), ('verde', 'verde'), ('giallo', 'amarillo'), ('bianco', 'blanco'), ('nero', 'negro'), ('notte', 'noche'), ('gi ...

# %%
translate = dict(it2es)
translate['noi']
# Out:
# 'nosotros'

# %%
translate['giocare']
# Out:
# 'jugar'

# %% [markdown]
# # WordNet

# %% [markdown]
# ## Referencias
#
# * [WordNet Lecture](https://sp1718.github.io/wordnet_lecture.pdf)
# * [What is WordNet?](https://wordnet.princeton.edu)
# * [WordNet Interface NLTK](http://www.nltk.org/howto/wordnet.html)
# * [LAS-WordNet](https://www.datos.gov.co/Ciencia-Tecnolog-a-e-Innovaci-n/LAS-WordNet-una-WordNet-para-el-espa-ol-obtenida-c/8z8d-85m7)

# %%
import nltk
nltk.download('omw')
nltk.download('wordnet')
nltk.download('omw-1.4') 
from nltk.corpus import wordnet as wn
# Out:
# [nltk_data] Downloading package omw to /home/rodri/nltk_data...
# [nltk_data]   Package omw is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/rodri/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/rodri/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# synset: grupo de sinómimos de una palabra.
ss = wn.synsets('carro', lang='spa')
ss
# Out:
# [Synset('car.n.01'),
#  Synset('carriage.n.04'),
#  Synset('carrier.n.02'),
#  Synset('cart.n.01'),
#  Synset('chariot.n.02'),
#  Synset('cartload.n.01')]

# %%
# explorando los synsets
for syn in ss:
  print(syn.name(), ': ', syn.definition())
  for name in syn.lemma_names():
    print(' * ', name) # sinónimos
# Out:
# car.n.01 :  a motor vehicle with four wheels; usually propelled by an internal combustion engine
#  *  car
#  *  auto
#  *  automobile
#  *  machine
#  *  motorcar
# carriage.n.04 :  a machine part that carries something else
#  *  carriage
# carrier.n.02 :  a self-propelled wheeled vehicle designed specifically to carry something
#  *  carrier
# cart.n.01 :  a heavy open wagon usually having two wheels and drawn by an animal
#  *  cart
# chariot.n.02 :  a two-wheeled horse-drawn battle vehicle; used in war and races in ancient Egypt and Greece and Rome
#  *  chariot
# cartload.n.01 :  the quantity that a cart holds
#  *  cartload

# %%
# visualization references
# * http://www.randomhacks.net/2009/12/29/visualizing-wordnet-relationships-as-graphs/
# * http://dlacombejr.github.io/programming/2015/09/28/visualizing-cifar-10-categories-with-wordnet-and-networkx.html

import networkx as nx
import matplotlib.pyplot as plt

def closure_graph(synset, fn):
    seen = set()
    graph = nx.DiGraph()
    labels = {}

    def recurse(s):
        if not s in seen:
            seen.add(s)
            labels[s.name] = s.name().split('.')[0]
            graph.add_node(s.name)
            for s1 in fn(s):
                graph.add_node(s1.name)
                graph.add_edge(s.name, s1.name)
                recurse(s1)

    recurse(synset)
    return graph, labels

def draw_text_graph(G, labels):
    plt.figure(figsize=(18,12))
    pos = nx.planar_layout(G, scale=18)
    nx.draw_networkx_nodes(G, pos, node_color="red", linewidths=0, node_size=500)
    nx.draw_networkx_labels(G, pos, font_size=20, labels=labels)
    nx.draw_networkx_edges(G, pos)
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ## **Hyponyms:** Conceptos que son más especificos que la palabra raiz de la cual derivan.

# %%
print(ss[0].name())
G, labels = closure_graph(ss[0], fn = lambda s: s.hyponyms())
draw_text_graph(G, labels)
# Out:
# car.n.01

# %% [markdown]
# ## **Hypernyms**: conceptos que son mas generales !

# %%
print(ss[0].name())
G, labels = closure_graph(ss[0], fn = lambda s: s.hypernyms())
draw_text_graph(G, labels)
# Out:
# car.n.01

# %% [markdown]
# ## Similitud Semántica

# %%
def show_syns(word):
  ss = wn.synsets(word, lang='spa')
  for syn in ss:
    print(syn.name(), ': ', syn.definition())
    for name in syn.lemma_names():
      print(' * ', name)
  return ss

# %%
ss = show_syns('perro')
# Out:
# dog.n.01 :  a member of the genus Canis (probably descended from the common wolf) that has been domesticated by man since prehistoric times; occurs in many breeds
#  *  dog
#  *  domestic_dog
#  *  Canis_familiaris
# rotter.n.01 :  a person who is deemed to be despicable or contemptible
#  *  rotter
#  *  dirty_dog
#  *  rat
#  *  skunk
#  *  stinker
#  *  stinkpot
#  *  bum
#  *  puke
#  *  crumb
#  *  lowlife
#  *  scum_bag
#  *  so-and-so
#  *  git

# %%
ss2 = show_syns('gato')
# Out:
# cat.n.01 :  feline mammal usually having thick soft fur and no ability to roar: domestic cats; wildcats
#  *  cat
#  *  true_cat
# tom.n.02 :  male cat
#  *  tom
#  *  tomcat
# dodger.n.01 :  a shifty deceptive person
#  *  dodger
#  *  fox
#  *  slyboots

# %%
ss3 = show_syns('animal')
# Out:
# animal.n.01 :  a living organism characterized by voluntary movement
#  *  animal
#  *  animate_being
#  *  beast
#  *  brute
#  *  creature
#  *  fauna
# beast.n.02 :  a cruelly rapacious person
#  *  beast
#  *  wolf
#  *  savage
#  *  brute
#  *  wildcat
# dunce.n.01 :  a stupid person; these words are used to express a low opinion of someone's intelligence
#  *  dunce
#  *  dunderhead
#  *  numskull
#  *  blockhead
#  *  bonehead
#  *  lunkhead
#  *  hammerhead
#  *  knucklehead
#  *  loggerhead
#  *  muttonhead
#  *  shithead
#  *  dumbass
#  *  fuckhead

# %%
perro = ss[0]
gato = ss2[0]
animal = ss3[0]

# %%
# similitud entre 'animal' y 'perro'
animal.path_similarity(perro)
# Out:
# 0.3333333333333333

# %%
# similitud entre 'animal' y 'gato'
animal.path_similarity(gato)
# Out:
# 0.125

# %%
perro.path_similarity(gato)
# Out:
# 0.2

# %%
perro.path_similarity(perro)
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
import networkx as nx

def traverse(graph, start, node):
    graph.depth[node.name] = node.shortest_path_distance(start)
    for child in node.hyponyms():
        graph.add_edge(node.name, child.name)
        traverse(graph, start, child)

def hyponym_graph(start):
    G = nx.Graph()
    G.depth = {}
    traverse(G, start, start)
    return G

def graph_draw(graph):
    # Replace draw_graphviz with draw
    pos = nx.spring_layout(graph)  # Use spring layout instead
    nx.draw(graph, 
            pos,
            node_size=[16*graph.degree(n) for n in graph],
            node_color=[graph.depth[n] for n in graph],
            with_labels=False)
    plt.show()

dog = wn.synset('dog.n.01')
graph = hyponym_graph(dog)
graph_draw(graph)
